# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import itertools
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap_external.py in _open_registry(cls, key)
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d3c3b97f812f> in <module>()
# ----> 1 import tensorflow as tf
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import numpy as np
#       5 import itertools
#
# C:\Users\wonjun\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>()
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 from tensorflow._api.v1 import app
#
# C:\Users\wonjun\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      70
#      71 # Ops
# ---> 72 from tensorflow.python.ops.standard_ops import *
#      73
#      74 # Namespaces
#
# C:\Users\wonjun\Anaconda3\lib\site-packages\tensorflow\python\ops\standard_ops.py in <module>()
#      23 import sys as _sys
#      24
# ---> 25 from tensorflow.python import autograph
#      26
#      27 # pylint: disable=g-bad-import-order
#
# C:\Users\wonjun\Anaconda3\lib\site-packages\tensorflow\python\autograph\__init__.py in <module>()
#      41 from tensorflow.python.autograph.core.errors import improved_errors
#      42 from tensorflow.python.autograph.core.errors import TfRuntimeError
# ---> 43 from tensorflow.python.autograph.impl.api import convert
#      44 from tensorflow.python.autograph.impl.api import converted_call
#      45 from tensorflow.python.autograph.impl.api import do_not_convert
#
# C:\Users\wonjun\Anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in <module>()
#      31 from tensorflow.python.autograph.core import config
#      32 from tensorflow.python.autograph.core import converter
# ---> 33 from tensorflow.python.autograph.impl import conversion
#      34 from tensorflow.python.autograph.operators import py_builtins
#      35 from tensorflow.python.autograph.pyct import compiler
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap_external.py in _search_registry(cls, fullname)
#
# C:\Users\wonjun\Anaconda3\lib\importlib\_bootstrap_external.py in _open_registry(cls, key)
#
# KeyboardInterrupt:

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, auc, roc_curve
from imblearn.over_sampling import ADASYN
# Out:
# Using TensorFlow backend.

# %%
def pre_PCA():
    dataset = pd.read_csv('data2.csv') #데이터셋 로딩, 간질환자의 발작 and 정상

    X = dataset.iloc[:,1:179].values
    y = dataset.iloc[:,179:].values

    for i in range(len(y)): #one-hot encoding
        if y[i] == 1 : 
            y[i] = 1
        else :
            y[i] = 0
        
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0) #8:2로 나눔
    
    #ADASYN 비대칭 데이터 문제 해결
    ad = ADASYN()
    X_train, y_train = ad.fit_sample(X_train, y_train)


    #주성분 추출
    pca = PCA() 
    pca.fit(X)
    cumsum = np.cumsum(pca.explained_variance_ratio_)
    d = np.argmax(cumsum >= 0.95)+1
    print('best dim =',d)

    pca = PCA(n_components= 39)

    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.fit_transform(X_test)
    
    return X_train_pca, X_test_pca, y_train, y_test

# %%
def pre_IPCA():
    dataset = pd.read_csv('data2.csv') #데이터셋 로딩, 간질환자의 발작 and 정상

    X = dataset.iloc[:,1:179].values
    y = dataset.iloc[:,179:].values

    for i in range(len(y)): #one-hot encoding
        if y[i] == 1 : 
            y[i] = 1
        else :
            y[i] = 0
        
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0) #8:2로 나눔

    #ADASYN 비대칭 데이터 문제 해결
    ad = ADASYN()
    X_train, y_train = ad.fit_sample(X_train, y_train)

    #주성분 추출
    n_batches = 10
    inc_pca = IncrementalPCA(n_components=39)

    for X_batch in np.array_split(X_train, n_batches):
        inc_pca.partial_fit(X_batch)
    
    for X_batch in np.array_split(X_test, n_batches):
        inc_pca.partial_fit(X_batch)
    
    X_train_ipca = inc_pca.transform(X_train)
    X_test_ipca = inc_pca.transform(X_test)
    
    return X_train_ipca, X_test_ipca, y_train, y_test

# %%
def clf(opt ,X_train, X_test,y_train, y_test, epochs):
    model = models.Sequential()
    model.add(layers.Dense(32, activation = 'relu', input_shape=(39,)))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(8, activation='relu'))
    model.add(layers.Dense(4, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer = opt,
                 loss='mse',
                 metrics=[metrics.binary_accuracy])

    history = model.fit(X_train,
                       y_train,
                       epochs = epochs,
                       batch_size = 10,
                       validation_data=(X_test,y_test))
    return history,model

# %%
def val_loss_acc(history, opt) :
    history_dict = history.history #딕셔너리를 만들어줍니다.
    history_dict.keys()
    history_dict = history.history #훈련과 검증 손실 그래프를 그려줍니다.
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']
    epochs = range(1,len(loss)+1)
    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title(opt + 'Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='best')
    plt.show()

    plt.clf() #그래프를 초기화합니다.
    acc = history_dict['binary_accuracy'] #훈련과 검증 정확도를 그려줍니다.
    val_acc = history_dict['val_binary_accuracy']
    plt.plot(epochs, acc,'r',label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='best')
    plt.show()

# %%
def roc(model) :
    pred_df = model.predict(X_test)
    fpr, tpr, thresholds = roc_curve(y_test, pred_df)
    roc_auc = auc(fpr, tpr)
    
    # Plotting ROC Curve
    plt.title('ROC & AUC')
    plt.plot(fpr, tpr, 'b', label='AUC = %0.3f' % roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([-0.05, 1.03])
    plt.ylim([-0.05, 1.03])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    # plt.savefig('SMOTE_lr_roc.png')
    plt.show()

# %%
X_train, X_test, y_train, y_test = pre_IPCA()
history,model = clf('Adam', X_train, X_test, y_train, y_test, 20) #분류기, X_train, X_test, y_train, y_test, epoch 순서로 넣으시면 됩니다.
val_loss_acc(history, 'Adam')
roc(model)

# %%
history,model = clf('Nadam', X_train, X_test, y_train, y_test, 20) #분류기, X_train, X_test, y_train, y_test, epoch 순서로 넣으시면 됩니다.
val_loss_acc(history)
roc(model)
# Out:
# Train on 3692 samples, validate on 920 samples
# Epoch 1/20
# 3692/3692 [==============================] - 4s 1ms/step - loss: 0.2272 - binary_accuracy: 0.7064 - val_loss: 0.1287 - val_binary_accuracy: 0.9185
# Epoch 2/20
# 3692/3692 [==============================] - 2s 485us/step - loss: 0.0952 - binary_accuracy: 0.9271 - val_loss: 0.0839 - val_binary_accuracy: 0.9380
# Epoch 3/20
# 3692/3692 [==============================] - 2s 455us/step - loss: 0.0663 - binary_accuracy: 0.9615 - val_loss: 0.0574 - val_binary_accuracy: 0.9663
# Epoch 4/20
# 3692/3692 [==============================] - 1s 268us/step - loss: 0.0448 - binary_accuracy: 0.9781 - val_loss: 0.0468 - val_binary_accuracy: 0.9739
# Epoch 5/20
# 3692/3692 [==============================] - 1s 293us/step - loss: 0.0332 - binary_accuracy: 0.9851 - val_loss: 0.0386 - val_binary_accuracy: 0.9707
# Epoch 6/20
# 3692/3692 [==============================] - 1s 252us/step - loss: 0.0258 - binary_accuracy: 0.9867 - val_loss: 0.0332 - val_binary_accuracy: 0.9761
# Epoch 7/20
# 3692/3692 [==============================] - 1s 263us/step - loss: 0.0205 - binary_accuracy: 0.9905 - val_loss: 0.0313 - val_binary_accuracy: 0.9739
# Epoch 8/20
# 3692/3692 [==============================] - 1s 257us/step - loss: 0.0168 - binary_accuracy: 0.9940 - val_loss: 0.0257 - val_binary_accuracy: 0.9793
# Epoch 9/20
# 3692/3692 [==============================] - 1s 270us/step - loss: 0.0128 - binary_accuracy: 0.9954 - val_loss: 0.0282 - val_binary_accuracy: 0.9685
# Epoch 10/20
# 3692/3692 [==============================] - 1s 280us/step - loss: 0.0110 - binary_accuracy: 0.9951 - val_loss: 0.0374 - val_binary_accuracy: 0.9641
# Epoch 11/20
# 3692/3692 [==============================] - 1s 186us/step - loss: 0.0106 - binary_accuracy: 0.9951 - val_loss: 0.0208 - val_binary_accuracy: 0.9783
# Epoch 12/20
# 3692/3692 [==============================] - 1s 159us/step - loss: 0.0095 - binary_accuracy: 0.9951 - val_loss: 0.0200 - val_binary_accuracy: 0.9848
# Epoch 13/20
# 3692/3692 [==============================] - 1s 157us/step - loss: 0.0097 - binary_accuracy: 0.9951 - val_loss: 0.0181 - val_binary_accuracy: 0.9793
# Epoch 14/20
# 3692/3692 [==============================] - 1s 156us/step - loss: 0.0061 - binary_accuracy: 0.9992 - val_loss: 0.0149 - val_binary_accuracy: 0.9837
# Epoch 15/20
# 3692/3692 [==============================] - 1s 147us/step - loss: 0.0044 - binary_accuracy: 0.9992 - val_loss: 0.0148 - val_binary_accuracy: 0.9815
# Epoch 16/20
# 3692/3692 [==============================] - 1s 148us/step - loss: 0.0035 - binary_accuracy: 0.9995 - val_loss: 0.0183 - val_binary_accuracy: 0.9761
# Epoch 17/20
# 3692/3692 [==============================] - 1s 162us/step - loss: 0.0029 - binary_accuracy: 0.9995 - val_loss: 0.0133 - val_binary_accuracy: 0.9870
# Epoch 18/20
# 3692/3692 [==============================] - 1s 149us/step - loss: 0.0029 - binary_accuracy: 0.9995 - val_loss: 0.0130 - val_binary_accuracy: 0.9870
# Epoch 19/20
# 3692/3692 [==============================] - 0s 130us/step - loss: 0.0020 - binary_accuracy: 0.9995 - val_loss: 0.0142 - val_binary_accuracy: 0.9870
# Epoch 20/20
# 3692/3692 [==============================] - 0s 131us/step - loss: 0.0034 - binary_accuracy: 0.9986 - val_loss: 0.0119 - val_binary_accuracy: 0.9848

# %%
history,model = clf('RMSProp', X_train, X_test, y_train, y_test, 20) #분류기, X_train, X_test, y_train, y_test, epoch 순서로 넣으시면 됩니다.
val_loss_acc(history)
roc(model)
# Out:
# Train on 3692 samples, validate on 920 samples
# Epoch 1/20
# 3692/3692 [==============================] - 3s 701us/step - loss: 0.2645 - binary_accuracy: 0.5390 - val_loss: 0.2404 - val_binary_accuracy: 0.5717
# Epoch 2/20
# 3692/3692 [==============================] - 1s 283us/step - loss: 0.2207 - binary_accuracy: 0.6054 - val_loss: 0.2176 - val_binary_accuracy: 0.5989
# Epoch 3/20
# 3692/3692 [==============================] - 1s 297us/step - loss: 0.1941 - binary_accuracy: 0.6804 - val_loss: 0.1972 - val_binary_accuracy: 0.7228
# Epoch 4/20
# 3692/3692 [==============================] - 1s 278us/step - loss: 0.1474 - binary_accuracy: 0.8055 - val_loss: 0.1332 - val_binary_accuracy: 0.8185
# Epoch 5/20
# 3692/3692 [==============================] - 1s 262us/step - loss: 0.1102 - binary_accuracy: 0.8919 - val_loss: 0.1086 - val_binary_accuracy: 0.9011
# Epoch 6/20
# 3692/3692 [==============================] - 1s 220us/step - loss: 0.0880 - binary_accuracy: 0.9317 - val_loss: 0.0888 - val_binary_accuracy: 0.9217
# Epoch 7/20
# 3692/3692 [==============================] - 1s 185us/step - loss: 0.0739 - binary_accuracy: 0.9407 - val_loss: 0.0913 - val_binary_accuracy: 0.9065
# Epoch 8/20
# 3692/3692 [==============================] - 1s 171us/step - loss: 0.0650 - binary_accuracy: 0.9477 - val_loss: 0.0790 - val_binary_accuracy: 0.9228
# Epoch 9/20
# 3692/3692 [==============================] - 1s 173us/step - loss: 0.0541 - binary_accuracy: 0.9542 - val_loss: 0.0670 - val_binary_accuracy: 0.9293
# Epoch 10/20
# 3692/3692 [==============================] - 1s 176us/step - loss: 0.0473 - binary_accuracy: 0.9569 - val_loss: 0.0724 - val_binary_accuracy: 0.9250
# Epoch 11/20
# 3692/3692 [==============================] - 1s 189us/step - loss: 0.0429 - binary_accuracy: 0.9618 - val_loss: 0.0667 - val_binary_accuracy: 0.9272
# Epoch 12/20
# 3692/3692 [==============================] - 1s 180us/step - loss: 0.0395 - binary_accuracy: 0.9653 - val_loss: 0.0655 - val_binary_accuracy: 0.9304
# Epoch 13/20
# 3692/3692 [==============================] - 1s 171us/step - loss: 0.0336 - binary_accuracy: 0.9710 - val_loss: 0.0623 - val_binary_accuracy: 0.9359
# Epoch 14/20
# 3692/3692 [==============================] - 1s 171us/step - loss: 0.0313 - binary_accuracy: 0.9707 - val_loss: 0.0549 - val_binary_accuracy: 0.9391
# Epoch 15/20
# 3692/3692 [==============================] - 1s 172us/step - loss: 0.0272 - binary_accuracy: 0.9745 - val_loss: 0.0502 - val_binary_accuracy: 0.9435
# Epoch 16/20
# 3692/3692 [==============================] - 1s 172us/step - loss: 0.0225 - binary_accuracy: 0.9808 - val_loss: 0.0481 - val_binary_accuracy: 0.9467
# Epoch 17/20
# 3692/3692 [==============================] - 1s 170us/step - loss: 0.0206 - binary_accuracy: 0.9802 - val_loss: 0.0511 - val_binary_accuracy: 0.9402
# Epoch 18/20
# 3692/3692 [==============================] - 1s 171us/step - loss: 0.0190 - binary_accuracy: 0.9821 - val_loss: 0.0512 - val_binary_accuracy: 0.9424
# Epoch 19/20
# 3692/3692 [==============================] - 1s 165us/step - loss: 0.0181 - binary_accuracy: 0.9829 - val_loss: 0.0462 - val_binary_accuracy: 0.9467
# Epoch 20/20
# 3692/3692 [==============================] - 1s 164us/step - loss: 0.0159 - binary_accuracy: 0.9854 - val_loss: 0.0433 - val_binary_accuracy: 0.9478

# %%
history,model = clf('AdaDelta', X_train, X_test, y_train, y_test, 20) #분류기, X_train, X_test, y_train, y_test, epoch 순서로 넣으시면 됩니다.
val_loss_acc(history)
roc(model)
# Out:
# Train on 3692 samples, validate on 920 samples
# Epoch 1/20
# 3692/3692 [==============================] - 5s 1ms/step - loss: 0.2385 - binary_accuracy: 0.5913 - val_loss: 0.2172 - val_binary_accuracy: 0.6337
# Epoch 2/20
# 3692/3692 [==============================] - 2s 434us/step - loss: 0.1730 - binary_accuracy: 0.7543 - val_loss: 0.1394 - val_binary_accuracy: 0.8750
# Epoch 3/20
# 3692/3692 [==============================] - 2s 476us/step - loss: 0.1103 - binary_accuracy: 0.9168 - val_loss: 0.1015 - val_binary_accuracy: 0.9022
# Epoch 4/20
# 3692/3692 [==============================] - 2s 525us/step - loss: 0.0747 - binary_accuracy: 0.9572 - val_loss: 0.0782 - val_binary_accuracy: 0.9261
# Epoch 5/20
# 3692/3692 [==============================] - 2s 448us/step - loss: 0.0530 - binary_accuracy: 0.9740 - val_loss: 0.0597 - val_binary_accuracy: 0.9554
# Epoch 6/20
# 3692/3692 [==============================] - 1s 384us/step - loss: 0.0393 - binary_accuracy: 0.9797 - val_loss: 0.0485 - val_binary_accuracy: 0.9598
# Epoch 7/20
# 3692/3692 [==============================] - 1s 348us/step - loss: 0.0302 - binary_accuracy: 0.9840 - val_loss: 0.0423 - val_binary_accuracy: 0.9641
# Epoch 8/20
# 3692/3692 [==============================] - 1s 298us/step - loss: 0.0234 - binary_accuracy: 0.9889 - val_loss: 0.0406 - val_binary_accuracy: 0.9576
# Epoch 9/20
# 3692/3692 [==============================] - 1s 274us/step - loss: 0.0193 - binary_accuracy: 0.9905 - val_loss: 0.0379 - val_binary_accuracy: 0.9609
# Epoch 10/20
# 3692/3692 [==============================] - 1s 309us/step - loss: 0.0158 - binary_accuracy: 0.9921 - val_loss: 0.0355 - val_binary_accuracy: 0.9620
# Epoch 11/20
# 3692/3692 [==============================] - 1s 298us/step - loss: 0.0134 - binary_accuracy: 0.9924 - val_loss: 0.0295 - val_binary_accuracy: 0.9696
# Epoch 12/20
# 3692/3692 [==============================] - 1s 289us/step - loss: 0.0113 - binary_accuracy: 0.9930 - val_loss: 0.0303 - val_binary_accuracy: 0.9685
# Epoch 13/20
# 3692/3692 [==============================] - 1s 281us/step - loss: 0.0096 - binary_accuracy: 0.9951 - val_loss: 0.0300 - val_binary_accuracy: 0.9696
# Epoch 14/20
# 3692/3692 [==============================] - 1s 287us/step - loss: 0.0086 - binary_accuracy: 0.9954 - val_loss: 0.0320 - val_binary_accuracy: 0.9641
# Epoch 15/20
# 3692/3692 [==============================] - 1s 290us/step - loss: 0.0080 - binary_accuracy: 0.9954 - val_loss: 0.0298 - val_binary_accuracy: 0.9707
# Epoch 16/20
# 3692/3692 [==============================] - 1s 284us/step - loss: 0.0068 - binary_accuracy: 0.9965 - val_loss: 0.0282 - val_binary_accuracy: 0.9685
# Epoch 17/20
# 3692/3692 [==============================] - 1s 302us/step - loss: 0.0061 - binary_accuracy: 0.9957 - val_loss: 0.0302 - val_binary_accuracy: 0.9663
# Epoch 18/20
# 3692/3692 [==============================] - 1s 261us/step - loss: 0.0056 - binary_accuracy: 0.9970 - val_loss: 0.0289 - val_binary_accuracy: 0.9663
# Epoch 19/20
# 3692/3692 [==============================] - 1s 249us/step - loss: 0.0047 - binary_accuracy: 0.9976 - val_loss: 0.0283 - val_binary_accuracy: 0.9685
# Epoch 20/20
# 3692/3692 [==============================] - 1s 259us/step - loss: 0.0045 - binary_accuracy: 0.9970 - val_loss: 0.0338 - val_binary_accuracy: 0.9609
